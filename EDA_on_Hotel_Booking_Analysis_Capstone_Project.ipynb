# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitWalde/EDA_on_Hotel_Booking.ipynb/blob/main/EDA_on_Hotel_Booking_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
#  **IMPORT LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **MOUNT DRIVE**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **SET FILE PATH**

# %%
file_path = '/content/drive/MyDrive/Almabetter/Capstone EDA Project/Explolatory Data Analysis on Hotel Bookings/Hotel Bookings.csv'

# %%
df = pd.read_csv(file_path)

# %% [markdown]
# * Now that we have the required data,I will take my first step to become a data scientist. WISH ME LUCK!!
#
# * First,let's make a copy of our data so our original file
# stay intact.

# %%
df_hotel = df.copy()

# %% [markdown]
# * We will have an overview of the data in the file.

# %%
df_hotel.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df_hotel.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# * Now we will see the data types of entries and null values in our columns.

# %%
df_hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# * Here we can see that there are a total of
# 119390 entries,in which there are 32 columns in the dataframe and columns like 'children','company','country' and 'agent' have null values.
#
# * Next,we will do a quick check on the given data.

# %%
df_hotel.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# **DATA DESCRIPTION**
# - **hotel** : Name of hotel ( City or Resort)
# - **is_canceled** : Whether the booking is canceled or not (0 for no canceled and 1 for canceled)
# - **lead_time** : time (in days) between booking transaction and actual arrival.
# - **arrival_date_year** : Year of arrival
# - **arrival_date_month** : month of arrival
# - **arrival_date_week_number** : week number of arrival date.
# - **arrival_date_day_of_month** : Day of month of arrival date
# - **stays_in_weekend_nights** : No. of weekend nights spent in a hotel
# - **stays_in_week_nights** : No. of weeknights spent in a hotel
# - **adults** : No. of adults in single booking record.
# - **children** : No. of children in single booking record.
# - **babies** : No. of babies in single booking record.
# - **meal** : Type of meal chosen
# - **country** : Country of origin of customers (as mentioned by them)
# - **market_segment** : What segment via booking was made and for what purpose.
# - **distribution_channel** : Via which medium booking was made.
# - **is_repeated_guest** : Whether the customer has made any booking before(0 for No and 1 for yes)
# - **previous_cancellations** : No. of previous canceled bookings.
# - **previous_bookings_not_canceled** : No. of previous non-canceled bookings.
# - **reserved_room_type** : Room type reserved by a customer.
# - **assigned_room_type** : Room type assigned to the customer.
# - **booking_changes** : No. of booking changes done by customers
# - **deposit_type** : Type of deposit at the time of making a booking (No deposit/ Refundable/ No refund)
# - **agent** : Id of agent for booking
# - **company** : Id of the company making a booking
# - **days_in_waiting_list** : No. of days on waiting list.
# - **customer_type** : Type of customer(Transient, Group, etc.)
# - **adr** : Average Daily rate.
# - **required_car_parking_spaces** : No. of car parking asked in booking
# - **total_of_special_requests** : total no. of special request.
# - **reservation_status** : Whether a customer has checked out or canceled,or not showed
# - **reservation_status_date** : Date of making reservation status.

# %%
# columns name list
print(list(df_hotel))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %% [markdown]
# * Finding unique values to better understand all the columns of the dataframe.

# %%
df_hotel['hotel'].unique()

# Also we can Find unique values in dataset using this code 
# df_new['column_name'].unique()
# but this method won't work on large no of columns
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
#another method for finding unique values
column_name=list(set(df_hotel.drop(columns=['reservation_status_date','country','arrival_date_month']).columns)-set(df_hotel.describe()))
for i in column_name:
  print(f'Unique values in column {i} are:, {(df_hotel[i].unique())}')
# Out:
# Unique values in column reservation_status are:, ['Check-Out' 'Canceled' 'No-Show']
# Unique values in column market_segment are:, ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# Unique values in column reserved_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']
# Unique values in column distribution_channel are:, ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# Unique values in column customer_type are:, ['Transient' 'Contract' 'Transient-Party' 'Group']
# Unique values in column assigned_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'P' 'L' 'K']
# Unique values in column hotel are:, ['Resort Hotel' 'City Hotel']
# Unique values in column meal are:, ['BB' 'FB' 'HB' 'SC' 'Undefined']
# Unique values in column deposit_type are:, ['No Deposit' 'Refundable' 'Non Refund']

# %% [markdown]
# *   There are a lot of duplicate data which  can affect the outcome of EDA needs to be deleted.
# *   Rows and column should be shaped .
# *   Removing the Null Values from the data.
#
# *  New important column for better analysing should be created.
# *  Conversion of column into  the new data type according to need.

# %% [markdown]
# ##Data Cleaning

# %%
# finding the duplicate rows
# True means duplicate rows
df_hotel.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
#dropping the duplicate rows
df_hotel = df_hotel.drop_duplicates()

# %%
#checking the column was drop or not
df_hotel.shape
# Out:
# (87396, 32)

# %%
df_hotel.isnull().sum().sort_values(ascending = False)[:8].reset_index()
# Out:
#                 index      0
# 0             company  82137
# 1               agent  12193
# 2             country    452
# 3            children      4
# 4  reserved_room_type      0
# 5  assigned_room_type      0
# 6     booking_changes      0
# 7        deposit_type      0

# %%
#filling null value in company,agent with 0
df_hotel[['company','agent']] = df_hotel[['company','agent']].fillna(0)

#filling country null value with others
new_columns = ['country']
for i in new_columns:
  df_hotel[i].fillna(0,inplace = True)

#filling children null value with mean
df_hotel['children'].fillna(df_hotel['children'].mean(),inplace = True)

# %%
#checking null values is change or not
df_hotel.isnull().sum().sort_values(ascending = False)[:8].reset_index()
# Out:
#                          index  0
# 0                        hotel  0
# 1                  is_canceled  0
# 2           reservation_status  0
# 3    total_of_special_requests  0
# 4  required_car_parking_spaces  0
# 5                          adr  0
# 6                customer_type  0
# 7         days_in_waiting_list  0

# %% [markdown]
# *There are some rows (babies,children or adults) is equal to zero. So we will remove this

# %%
#checking the total number of rows which containing value equal to 0
df_hotel[df_hotel['babies']+df_hotel['children']+df_hotel['adults'] == 0].shape
# Out:
# (166, 32)

# %%
#dropping those rows
df_hotel.drop(df_hotel[df_hotel['babies']+df_hotel['children']+df_hotel['adults'] == 0].index, inplace = True)

# %%
#add some new columns
df_hotel['total_people'] = df_hotel['babies']+df_hotel['children']+df_hotel['adults']
df_hotel['total_stay'] = df_hotel['stays_in_weekend_nights'] + df_hotel['stays_in_week_nights']

# %% [markdown]
# * By adding this we can analyse better the total stay length of hotel

# %%
#checking the new columns has added
df_hotel.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  company  \
# 0                        0                     0       2  ...      0.0
# ...

# %%
#checking the final shape of rows and columns
df_hotel.shape
# Out:
# (87230, 34)

# %% [markdown]
# ##**Exploratory Data Analysis**
